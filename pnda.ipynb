# %%
import pandas as pd

# %%
df = pd.read_csv('pandas/auto_policy_1.csv')
df
# Out:
#    PolicyID     CustomerName               CarModel  CarYear FuelType  \
# 0       101        Arun Nair     Maruti Suzuki Alto     2018   Petrol
# 1       102      Biju Pillai             Honda City     2020   Diesel
# 2       103       Ravi Kumar          Hyundai Creta     2021   Petrol
# 3       104    Shalini Menon          Toyota Innova     2020   Diesel
# 4       105    Rama Krishnan          Ford EcoSport     2019   Petrol
# 5       106     Vijay Thomas          Mahindra Thar     2021       EV
# 6       107         Anjali R           Suzuki Swift     2020   Petrol
# 7       108    Suresh Prasad         Nissan Magnite     2018   Petrol
# 8       109  Geethu Varghese                 BMW X5     2022   Petrol
# 9       110          Manoj K  Mercedes Benz A-Class     2021   Petrol
#
#     StartDate     EndDate  PremiumAmount
# 0  2024-10-01  2025-10-01            450
# 1  2024-10-31  2025-10-31            500
# 2  2024-11-30  2025-11-30            550
# ...

# %%
df = pd.read_csv('pandas/auto_policy_1.csv', usecols=["PolicyID", "CustomerName"])
df
df.head()
# Out:
#    PolicyID   CustomerName
# 0       101      Arun Nair
# 1       102    Biju Pillai
# 2       103     Ravi Kumar
# 3       104  Shalini Menon
# 4       105  Rama Krishnan

# %%
# row and colum index
df.head()
# Out:
#    PolicyID   CustomerName
# 0       101      Arun Nair
# 1       102    Biju Pillai
# 2       103     Ravi Kumar
# 3       104  Shalini Menon
# 4       105  Rama Krishnan

# %%
#for descriptive statistics
df.describe()
# Out:
#         PolicyID
# count   10.00000
# mean   105.50000
# std      3.02765
# min    101.00000
# 25%    103.25000
# 50%    105.50000
# 75%    107.75000
# max    110.00000
